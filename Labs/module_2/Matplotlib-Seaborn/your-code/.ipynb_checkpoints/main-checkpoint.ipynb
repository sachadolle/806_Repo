# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
z
# Out:
# array([   0,    1,    4,    9,   16,   25,   36,   49,   64,   81,  100,
#         121,  144,  169,  196,  225,  256,  289,  324,  361,  400,  441,
#         484,  529,  576,  625,  676,  729,  784,  841,  900,  961, 1024,
#        1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849,
#        1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916,
#        3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225,
#        4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776,
#        5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569,
#        7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604,
#        9801], dtype=int32)

# %%
import matplotlib.pyplot as plt
plt.plot(x, y, label='xy')
plt.plot(y, z, label='yz')

# %%
import seaborn as sns
sns.set()

# %%
sns.lineplot(x, y)
sns.lineplot(y,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
fig, axes=plt.subplots(1,2)
axes[0].plot(x, y)
axes[1].plot(y,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, axes=plt.subplots(1,2, figsize=(15,15))
plt.title('x, y and z')
plt.rc('font', weight='bold')
plt.rc('lines', lw=2, color='g')
axes[0].plot(x, y)
axes[0].set_xlabel('x axis')
axes[0].set_ylabel('y axis')
axes[1].plot(y, z)
axes[1].set_xlabel('x axis')
axes[1].set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x=np.arange(0,100)
y=x**2
sns.set()
sns.lineplot(x, y)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv(r'C:\Users\Sacha.dolle\Desktop\Cours IH\Cours\Week 4\Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit.corr().head()
# Out:
#                    Calorie burned     Steps  Distance    Floors  \
# Calorie burned           1.000000  0.255305  0.292790  0.130757
# Steps                    0.255305  1.000000  0.779678  0.306511
# Distance                 0.292790  0.779678  1.000000  0.382940
# Floors                   0.130757  0.306511  0.382940  1.000000
# Minutes Sedentary        0.125353  0.076906  0.160632  0.057812
#
#                    Minutes Sedentary  Minutes Lightly Active  \
# Calorie burned              0.125353                0.209540
# Steps                       0.076906                0.393010
# Distance                    0.160632                0.455272
# Floors                      0.057812               -0.085992
# Minutes Sedentary           1.000000                0.217021
#
#                    Minutes Fairly Active  Minutes Very Active  \
# Calorie burned                  0.188256             0.197881
# Steps                           0.303244             0.571452
# ...

# %%
# MEDIAN STEPS BY MONTH_ENCODED
#sns.lmplot('Steps', 'Months_encoded', data=fitbit, fit_reg=True)

wowe=fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median().reset_index()
month=fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').median().reset_index()

plt.bar('Steps', 'Work_or_Weekend', data=fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median().reset_index())
#sns.scatterplot('Steps', 'Months_encoded', data=fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').median().reset_index())


#estimator=np.mean
"""
# MEDIAN STEPS BY WORK_OR_WEEKEND
sns.lmplot('Steps', 'Work_or_Weekend', data=fitbit, fit_reg=True)

#fitbit['Work_or_Weekend']=fitbit['Work_or_Weekend'].replace(1, 'work')
#fitbit['Work_or_Weekend']=fitbit['Work_or_Weekend'].replace(0, 'weekend')
#fitbit['Work_or_Weekend'].str.get_dummies()
#sns.scatterplot(fitbit.Steps, fitbit['Work_or_Weekend'], data=fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median())

plt.figure(figsize=(12,4))

plt.savefig("fitbit.png"
"""
# Out:
# '\n# MEDIAN STEPS BY WORK_OR_WEEKEND\nsns.lmplot(\'Steps\', \'Work_or_Weekend\', data=fitbit, fit_reg=True)\n\n#fitbit[\'Work_or_Weekend\']=fitbit[\'Work_or_Weekend\'].replace(1, \'work\')\n#fitbit[\'Work_or_Weekend\']=fitbit[\'Work_or_Weekend\'].replace(0, \'weekend\')\n#fitbit[\'Work_or_Weekend\'].str.get_dummies()\n#sns.scatterplot(fitbit.Steps, fitbit[\'Work_or_Weekend\'], data=fitbit[[\'Work_or_Weekend\', \'Steps\']].groupby(\'Work_or_Weekend\').median())\n\nplt.figure(figsize=(12,4))\n\nplt.savefig("fitbit.png"\n'

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median().reset_index()
bars2 = fitbit[['Months_encoded', 'Steps']].groupby('Months_encoded').median().reset_index()
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Work or Weekend')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Months')
 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B'])
 
# Create legend & Show graphic
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4d8087fc1ef1> in <module>
#      15
#      16 # Make the plot
# ---> 17 plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Work or Weekend')
#      18 plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Months')
#      19
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
fitbit[['Work_or_Weekend', 'Steps']].groupby('Work_or_Weekend').median().reset_index()
# Out:
#    Work_or_Weekend    Steps
# 0                0   9998.0
# 1                1  10445.5

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
