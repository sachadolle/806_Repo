ess=h%3DCD951%26c%3Dbrand%26v%3D%26t%3D0%26s%3D; _gcl_aw=GCL.1593091602.CjwKCAjwltH3BRB6EiwAhj0IUGsR6vURYbU9LVMbdnWTsRtm1p10XdffWar1Ha98bkltf-6e0fgjixoCdMcQAvD_BwE; TFE_DATE_FROM=; __utmzz=utmcsr=google|utmcmd=cpc|utmccn=(not set)|utmgclid=CjwKCAjwltH3BRB6EiwAhj0IUG6l-kglgUUfdiJLQaWs4Eq6NpV8pY13cBvjbnKzjTHeuQbQZjo4IRoCiZcQAvD_BwE; _gac_UA-10653869-1=1.1593113729.CjwKCAjwltH3BRB6EiwAhj0IUG6l-kglgUUfdiJLQaWs4Eq6NpV8pY13cBvjbnKzjTHeuQbQZjo4IRoCiZcQAvD_BwE; ab.storage.deviceId.32b57c7b-1181-4973-9f07-79cdd6d2c403=%7B%22g%22%3A%22b54da508-4049-66ad-b38e-d88dd8859c56%22%2C%22c%22%3A1593113728833%2C%22l%22%3A1593113728833%7D; _hjAbsoluteSessionInProgress=1; OptanonConsent=isIABGlobal=false&datestamp=Thu+Jun+25+2020+15:27:07+GMT+0200+(heure+d’été+d’Europe+centrale)&version=6.0.0&landingPath=NotLandingPage&groups=C0001:1,C0002:1,C0004:1,C0003:1&hosts=&legInt=&consentId=df6cfbde-8a14-48d9-baa0-397fb67e09de&interactionCount=1&AwaitingReconsent=false=undefined&legInt=&datestamp=Thu+Jun+25+2020+21%3A35%3A38+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=6.0.0; ab.storage.sessionId.32b57c7b-1181-4973-9f07-79cdd6d2c403=%7B%22g%22%3A%2260724f19-f93f-7e05-2fe7-a56dfbe94c5a%22%2C%22e%22%3A1593115540123%2C%22c%22%3A1593112411091%2C%22l%22%3A1593113740123%7D
pragma: no-cache
referer: https://www.getyourguide.fr/s/?q=France&cmp=brand&partner_id=CD951&searchSource=2&p=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36
x-csrf-token: bf0dba03cf76cce9eee681b827d57ae12173d9133a2ab75d15f653f616aa7227e9fee60c15bee8891fb692912145872bc3cb29f212f3128c781a4b8bd22abbbc
x-gyg-ap-cntnr: Search
x-gyg-ap-vid: 697ce7200252a650d8854972e012f660
x-requested-with: XMLHttpRequest"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))
headers
# Out:
# {'accept': '*/*',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
#  'cache-control': 'no-cache',
# ...

# %%
response = r.get(url, headers=headers).json()
norm=json_normalize(response)
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
norm
# Out:
#                                                items  \
# 0  [{'id': 527101465, 'title': 'Magnifique jupe L...
#
#                   search_correlation_id                     search_session_id  \
# 0  39e73c62-efd2-4c6e-8c10-eeb56adc0fc3  9fa05250-b3c6-45ed-9c68-f2be12e383c2
#
#    code item_scores_by_id.527101465 item_scores_by_id.527101462  \
# 0     0                        None                        None
#
#   item_scores_by_id.527101456 item_scores_by_id.527101448  \
# 0                        None                        None
#
#   item_scores_by_id.527101446 item_scores_by_id.527101445  ...  \
# 0                        None                        None  ...
#
#   item_scores_by_id.527101408 item_scores_by_id.527101403  \
# 0                        None                        None
#
#   item_scores_by_id.527101400 item_scores_by_id.527101396  \
# 0                        None                        None
#
# ...

# %%
norm2=json_normalize(norm['items'][0])
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
pd.set_option('display.max_row', None)
norm2.T
# Out:
#                                                                                         0   \
# id                                                                               527101465
# title                                                    Magnifique jupe Longue Vero Moda
# brand_id                                                                                55
# size_id                                                                                  3
# status_id                                                                                6
# disposal_conditions                                                                      4
# user_id                                                                           16407540
# owner_id                                                                              None
# country_id                                                                              16
# ...

# %%
import time

#data collection
df=pd.DataFrame()
step=0 # dummy to detect be patient
for i in range(400): #guess because blocked by the website
    url=f'https://www.vinted.fr/api/v2/items?catalog_ids=1904&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&page={i}&per_page=24&time=1592944597&search_session_id=9fa05250-b3c6-45ed-9c68-f2be12e383c2'    
    response = r.get(url, headers=headers)
    step+=1
    if step%5==0:
        time.sleep(2.4) # sleep every five parsed page
        print (step, 'pages loaded')
    results = response.json()
    flattened_data = json_normalize(results)
    df = df.append(flattened_data)
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# 5 pages loaded
# 10 pages loaded
# 15 pages loaded
# 20 pages loaded
# 25 pages loaded
# 30 pages loaded
# 35 pages loaded
# 40 pages loaded
# 45 pages loaded
# 50 pages loaded
# 55 pages loaded
# 60 pages loaded
# 65 pages loaded
# 70 pages loaded
# 75 pages loaded
# 80 pages loaded
# 85 pages loaded
# 90 pages loaded
# 95 pages loaded
# 100 pages loaded
# 105 pages loaded
# 110 pages loaded
# 115 pages loaded
# 120 pages loaded
# 125 pages loaded
# 130 pages loaded
# 135 pages loaded
# 140 pages loaded
# 145 pages loaded
# 150 pages loaded
# 155 pages loaded
# 160 pages loaded
# 165 pages loaded
# 170 pages loaded
# 175 pages loaded
# 180 pages loaded
# 185 pages loaded
# 190 pages loaded
# 195 pages loaded
# 200 pages loaded
# 205 pages loaded
# 210 pages loaded
# 215 pages loaded
# 220 pages loaded
# ...

# %%
df
# Out:
#     code                            message                  message_code
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# ..   ...                                ...                           ...
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
# 0    100  Token d'authentification invalide  invalid_authentication_token
#
# [400 rows x 3 columns]
