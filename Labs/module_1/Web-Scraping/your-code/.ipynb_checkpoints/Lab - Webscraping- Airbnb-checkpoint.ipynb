# %% [markdown]
# # Scrap all the objects of Airbnb

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url='https://www.airbnb.fr/api/v3/ExploreSearch?locale=fr&operationName=ExploreSearch&currency=EUR&variables=%7B%22request%22%3A%7B%22metadataOnly%22%3Afalse%2C%22version%22%3A%221.7.6%22%2C%22itemsPerGrid%22%3A20%2C%22tabId%22%3A%22all_tab%22%2C%22cdnCacheSafe%22%3Afalse%2C%22simpleSearchTreatment%22%3A%22simple_search_only%22%2C%22treatmentFlags%22%3A%5B%5D%2C%22screenSize%22%3A%22large%22%7D%7D&extensions=%7B%22persistedQuery%22%3A%7B%22version%22%3A1%2C%22sha256Hash%22%3A%22f792efc82258a7dcd76bca8c2d9f194012bd860ee8a12db9a00823e41163916c%22%7D%7D'

# %%
headers="""accept: */*
content-type: application/json
Device-Memory: 8
DPR: 1
ect: 4g
Referer: https://www.airbnb.fr/
User-Agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36
Viewport-Width: 811
X-Airbnb-API-Key: d306zoyjsyarp7ifhu67rjxn52tv0t20
X-Airbnb-GraphQL-Platform: web
X-Airbnb-GraphQL-Platform-Client: apollo-niobe
X-CSRF-Token: V4$.airbnb.fr$wtJQRQ2NybQ$R3fI3SSLlvrqTvi3Oi_Bwo75o3mrgNhOm3KFFI9CiwE=
X-CSRF-Without-Token: 1"""

# %%
headers=dict(i.split(': ') for i in headers.split('\n'))
print(headers)
# Out:
# {'accept': '*/*', 'content-type': 'application/json', 'Device-Memory': '8', 'DPR': '1', 'ect': '4g', 'Referer': 'https://www.airbnb.fr/', 'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36', 'Viewport-Width': '811', 'X-Airbnb-API-Key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20', 'X-Airbnb-GraphQL-Platform': 'web', 'X-Airbnb-GraphQL-Platform-Client': 'apollo-niobe', 'X-CSRF-Token': 'V4$.airbnb.fr$wtJQRQ2NybQ$R3fI3SSLlvrqTvi3Oi_Bwo75o3mrgNhOm3KFFI9CiwE=', 'X-CSRF-Without-Token': '1'}

# %%
response = requests.get(url, headers=headers) # access the website using the link and headers collected from the website 
response
# Out:
# <Response [200]>

# %%
results = response.json() #transform the obtained data into json file

# %%
flattened_data = json_normalize(results) #normalize the data (transform it into readable format)
pd.set_option('display.max_rows', None)
flattened_data.T
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                                                                                     0
# data.dora.__typename                                                                        DoraQuery
# data.dora.exploreV3.__typename                                                  DoraExploreV3Response
# data.dora.exploreV3.exploreMap.__typename                                            DoraExploreV3Map
# data.dora.exploreV3.exploreMap.isMapToggled                                                     False
# data.dora.exploreV3.exploreMap.isMapEnabled                                                     False
# data.dora.exploreV3.educationOverlay.__typename                                  DoraEducationOverlay
# ...

# %%
#data.dora.exploreV3.searchHeader.searchInputFlow.steps
#data.dora.exploreV3.searchHeader.searchInputFlow.metadata.verticalPicker.verticalCards
#data.dora.exploreV3.sections

# %%
flattened_data['data.dora.exploreV3.sections'][0]
# Out:
# [{'__typename': 'DoraExploreV3ListHeadersSection',
#   'loggingContext': {'__typename': 'DoraExploreV3SectionLoggingContext',
#    'backendSearchId': '9a56bca1-541b-4437-96e2-73cfe5da4c86',
#    'searchSessionId': '5abe09ec-d1c2-49e5-83a2-aeef4cc7eb71',
#    'sectionId': '5abe09ec-d1c2-49e5-83a2-aeef4cc7eb71',
#    'sectionTypeUid': None,
#    'bankaiSectionId': '221952'},
#   'resultTypeDeprecated': 'list_headers',
#   'sectionComponentType': 'list_headers_TEXT_NO_IMAGE',
#   'sectionComponentTypeV2': 'LIST_HEADERS_THERMAL_TEXT_V2',
#   'sectionMetadata': {'__typename': 'DoraSectionMetadata',
#    'campaignName': None,
#    'cardLayout': None,
#    'carouselItemSize': None,
#    'isMimickingPaginated': False,
#    'marqueeDuration': None,
#    'pollingInfo': None,
#    'seeAllButtonOutlineColor': None,
#    'seeAllButtonTextColor': None,
#    'seeAllLinkTextColor': None,
#    'shouldHideItemsFromMap': False},
#   'experimentsMetadata': [],
#   'title': None,
#   'subtitle': None,
# ...

# %%
data=json_normalize(flattened_data['data.dora.exploreV3.sections'][0])
pd.set_option('display.max_columns', None)
data
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                     __typename       resultTypeDeprecated  \
# 0              DoraExploreV3ListHeadersSection               list_headers
# 1            DoraExploreV3EarhartInsertSection            earhart_inserts
# 2            DoraExploreV3EarhartInsertSection            earhart_inserts
# 3            DoraExploreV3EarhartInsertSection            earhart_inserts
# 4  DoraExploreV3NavigationLinkGroupingsSection  navigation_link_groupings
#
#                                 sectionComponentType  \
# 0                         list_headers_TEXT_NO_IMAGE
# 1               earhart_inserts_EARHART_INSERTS_CARD
# 2               earhart_inserts_EARHART_INSERTS_CARD
# 3  earhart_inserts_EARHART_INSERTS_FULL_BLEED_BOT...
# ...

# %%
data['items']
# Out:
# 0    [{'__typename': 'DoraListHeaderItem', 'breakpo...
# 1    [{'__typename': 'DoraEarhartInsertItem', 'back...
# 2    [{'__typename': 'DoraEarhartInsertItem', 'back...
# 3    [{'__typename': 'DoraEarhartInsertItem', 'back...
# 4    [{'__typename': 'DoraNavigationLinkGroupingIte...
# Name: items, dtype: object

# %%
data['items'][0]
# Out:
# [{'__typename': 'DoraListHeaderItem',
#   'breakpointConfigStruct': {'__typename': 'DoraBreakpointConfigStruct',
#    'default': {'__typename': 'DoraBreakpointConfig',
#     'ctaTextColor': '#484848',
#     'kickerTextColor': None,
#     'logoColor': '#484848',
#     'subtitleTextColor': '#484848',
#     'titleTextColor': '#484848'},
#    'small': {'__typename': 'DoraBreakpointConfig',
#     'ctaTextColor': '#484848',
#     'kickerTextColor': None,
#     'logoColor': '#484848',
#     'subtitleTextColor': '#484848',
#     'titleTextColor': '#484848'},
#    'medium': None,
#    'large': {'__typename': 'DoraBreakpointConfig',
#     'ctaTextColor': '#484848',
#     'kickerTextColor': None,
#     'logoColor': '#484848',
#     'subtitleTextColor': '#484848',
#     'titleTextColor': '#484848'}},
#   'mediumBackgroundImage': None,
#   'smallBackgroundImage': None,
#   'largeBackgroundImage': None,
#   'ctaText': None,
#   'ctaType': None,
#   'ctaUrl': None,
#   'isAboveMap': False,
# ...

# %%
data['items'][1]
# Out:
# [{'__typename': 'DoraEarhartInsertItem',
#   'backgroundColor': '#ffffff',
#   'badge': {'__typename': 'DoraEarhartBadge',
#    'backgroundColor': '#ffffff',
#    'text': 'NOUVEAU',
#    'textColor': '#222222'},
#   'canonicalUrl': None,
#   'ctaColor': None,
#   'ctaFont': None,
#   'ctaStyle': None,
#   'ctaText': None,
#   'ctaType': 'search',
#   'ctaUrl': None,
#   'imageTitle': None,
#   'kicker': None,
#   'kickerColor': None,
#   'kickerFont': None,
#   'logoImageConfig': None,
#   'mediaAspectRatio': None,
#   'mediumPicture': None,
#   'largePicture': None,
#   'xLargePicture': None,
#   'pictures': [{'__typename': 'DoraEarhartPicture',
#     'small': None,
#     'medium': 'https://a0.muscache.com/pictures/ef0ee86b-feba-47f8-8882-014b2a7b6926.jpg',
#     'large': 'https://a0.muscache.com/im/pictures/ef0ee86b-feba-47f8-8882-014b2a7b6926.jpg?aki_policy=large',
#     'xLarge': 'https://a0.muscache.com/im/pictures/ef0ee86b-feba-47f8-8882-014b2a7b6926.jpg?aki_policy=x_large'}],
# ...

# %%
data['items'][2]
# Out:
# [{'__typename': 'DoraEarhartInsertItem',
#   'backgroundColor': None,
#   'badge': None,
#   'canonicalUrl': None,
#   'ctaColor': None,
#   'ctaFont': None,
#   'ctaStyle': None,
#   'ctaText': None,
#   'ctaType': 'search',
#   'ctaUrl': '/experiences/1691219',
#   'imageTitle': None,
#   'kicker': None,
#   'kickerColor': None,
#   'kickerFont': None,
#   'logoImageConfig': None,
#   'mediaAspectRatio': 1,
#   'mediumPicture': {'__typename': 'DoraEarhartPicture',
#    'large': 'https://a0.muscache.com/im/pictures/d3fafe53-6348-4dcb-b778-e6724eb25a4a.jpg?aki_policy=large'},
#   'largePicture': {'__typename': 'DoraEarhartPicture',
#    'large': 'https://a0.muscache.com/im/pictures/d3fafe53-6348-4dcb-b778-e6724eb25a4a.jpg?aki_policy=large'},
#   'xLargePicture': {'__typename': 'DoraEarhartPicture',
#    'large': 'https://a0.muscache.com/im/pictures/d3fafe53-6348-4dcb-b778-e6724eb25a4a.jpg?aki_policy=large'},
#   'pictures': [{'__typename': 'DoraEarhartPicture',
#     'small': None,
# ...

# %%
data['items'][3]
# Out:
# [{'__typename': 'DoraEarhartInsertItem',
#   'backgroundColor': None,
#   'badge': None,
#   'canonicalUrl': None,
#   'ctaColor': None,
#   'ctaFont': None,
#   'ctaStyle': None,
#   'ctaText': None,
#   'ctaType': None,
#   'ctaUrl': None,
#   'imageTitle': None,
#   'kicker': None,
#   'kickerColor': None,
#   'kickerFont': None,
#   'logoImageConfig': None,
#   'mediaAspectRatio': 1,
#   'mediumPicture': {'__typename': 'DoraEarhartPicture',
#    'large': 'https://a0.muscache.com/im/pictures/197f837b-3bef-4a32-93f3-c93270d58245.jpg?aki_policy=large'},
#   'largePicture': {'__typename': 'DoraEarhartPicture',
#    'large': 'https://a0.muscache.com/im/pictures/197f837b-3bef-4a32-93f3-c93270d58245.jpg?aki_policy=large'},
#   'xLargePicture': None,
#   'pictures': [{'__typename': 'DoraEarhartPicture',
#     'small': None,
#     'medium': 'https://a0.muscache.com/pictures/197f837b-3bef-4a32-93f3-c93270d58245.jpg',
# ...

# %%
data['items'][4]
# Out:
# [{'__typename': 'DoraNavigationLinkGroupingItem',
#   'title': 'Pour les voyageurs',
#   'seeAllLink': None,
#   'navigationLinks': [{'__typename': 'DoraNavigationLinkItem',
#     'airmoji': None,
#     'badge': None,
#     'description': "Ce qu'il faut savoir",
#     'image': None,
#     'picture': None,
#     'searchParams': None,
#     'subtitle': None,
#     'title': '<b>Informations pour les voyages</b>',
#     'url': 'https://www.airbnb.fr/covid',
#     'urlType': 'static_link'},
#    {'__typename': 'DoraNavigationLinkItem',
#     'airmoji': None,
#     'badge': None,
#     'description': 'Découvrir ce qui est couvert',
#     'image': None,
#     'picture': None,
#     'searchParams': None,
#     'subtitle': None,
#     'title': "<b>Options d'annulation</b>",
#     'url': 'https://www.airbnb.fr/help/article/2701/extenuating-circumstances-policy-and-the-coronavirus-covid19',
#     'urlType': 'static_link'},
#    {'__typename': 'DoraNavigationLinkItem',
#     'airmoji': None,
# ...

# %%
data['items'][5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-fa5cf7f03d04> in <module>
# ----> 1 data['items'][5]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# ...

# %%
data1=list(json_normalize(data['items'][0]))
data2=list(json_normalize(data['items'][1]))
data3=list(json_normalize(data['items'][2]))
data4=list(json_normalize(data['items'][3]))
data5=list(json_normalize(data['items'][4]))
# Out:
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# ...

# %%
df=pd.DataFrame({'data1':data1, 'data2':data2, 'data3':data3, 'data4':data4, 'data5':data5})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-96169d4249ee> in <module>
# ----> 1 df=pd.DataFrame({'data1':data1, 'data2':data2, 'data3':data3, 'data4':data4, 'data5':data5})
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
# ...
