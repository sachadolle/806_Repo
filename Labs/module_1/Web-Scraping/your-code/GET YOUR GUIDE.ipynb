# %%
import requests as r
import pandas as pd
import json
from pandas.io.json import json_normalize
import re
from bs4 import BeautifulSoup
import math

# %%
headers="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: PHPSESSID=5v0907emsmhjb91ab8af2uvu1q; locale_code=fr-FR; platform=desktop; par_sess=h%3D-%26c%3D%26v%3D%26t%3D0%26s%3D; partner_expires=2678400; partner_id=-; cur=EUR; visitor_id=4H8ABT3TO1R9Z46DVEXN6GS3OMQ43SF6; browser_support=modern; AP-VID=c73c70fc349b026bf93853cdfbae8931; _gcl_au=1.1.146597312.1593160775; HIA=IPv4-FR-00000002-9b4357007c325c99a0ada28b47f0e79025fe2b12834a1e76899d8c4f15a0e1229639237d592f46c6c4ba4c1807814c8fba99ca121a439f14acca54aa7074793b; isMobile=false; is_office_ip=false; TFE_DATE_FROM=; ab.storage.deviceId.32b57c7b-1181-4973-9f07-79cdd6d2c403=%7B%22g%22%3A%224850bf39-d263-58da-544a-779c0e1e6310%22%2C%22c%22%3A1593160777028%2C%22l%22%3A1593160777028%7D; ab.storage.sessionId.32b57c7b-1181-4973-9f07-79cdd6d2c403=%7B%22g%22%3A%223d8936ee-6572-9a1e-23f1-28f6f777f563%22%2C%22e%22%3A1593162577098%2C%22c%22%3A1593160777020%2C%22l%22%3A1593160777098%7D; __ssid=5da2157da6677e7046f2a10f8816cf5; one_tap_first_access=2020-06-26T08:39:39.227Z; OptanonConsent=isIABGlobal=false&datestamp=Fri+Jun+26+2020+10%3A40%3A02+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=6.0.0&landingPath=https%3A%2F%2Fwww.getyourguide.fr%2Fdiscovery%2F%3Futm_force%3D0&groups=C0001%3A1%2CC0002%3A1%2CC0004%3A1%2CC0003%3A1&hosts=&legInt=&consentId=27af5126-9eb2-4fc1-b5c0-879037c5e899&interactionCount=0; SESSDATA=XvW0YQ.....ZivZN7IzZmPRbsEML2dh2VVJZofV8DJRDDO4JBFfcZc
pragma: no-cache
referer: https://www.getyourguide.fr/s/?q=France&searchSource=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36
x-csrf-token: b2696f888a0b6e75379f042ed86783d8838806e6165b85c511979d064c7eba905ae6a829c5343372eae88da600d9ba0d8945a1193e7c0eb09c0bc1a19145ee68
x-gyg-ap-cntnr: Search
x-gyg-ap-vid: f996b1003ac662e5ec4945fb63fd5976
x-requested-with: XMLHttpRequest"""

headers=dict(i.split(': ') for i in headers.split('\n'))

# %%
import time

df=pd.DataFrame()
step=0
total_elements=1610
element_p_page=20
pagination=math.ceil(total_elements/element_p_page)+1

for i in range(pagination):
    url=f'https://www.getyourguide.fr/s/results.json?&q=France&searchSource=2&p={i}&page={math.floor(i/3.01)}'    
    resp=r.get(url, headers=headers)
    
    if step%5==0:
        time.sleep(2.4) # sleep every five parsed page
        print (step, 'pages loaded')
        
    results=resp.json()
    data=json_normalize(results['searchResults']['tours'])
    df=df.append(data)

    step+=1
# Out:
# 0 pages loaded
# C:\Users\Sacha.dolle\anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# 5 pages loaded
# 10 pages loaded
# 15 pages loaded
# 20 pages loaded
# 25 pages loaded
# 30 pages loaded
# 35 pages loaded
# 40 pages loaded
# 45 pages loaded
# 50 pages loaded
# 55 pages loaded
# 60 pages loaded
# 65 pages loaded
# 70 pages loaded
# 75 pages loaded
# 80 pages loaded

# %%
# COLUMNS

df=df.drop_duplicates(subset='tourId')

df=df.drop(columns=['tourId', 'horizontalImageUrl', 'verticalImageUrl', 'mobileImageUrl', 'horizontalSlimImageUrl', \
                 'description', 'isBestseller', 'isFeatured', 'hasDeal', 'dealMaxPercentage', 'isBoostedNewTour', 'hasBanner', \
                 'hasRibbon', 'priceTag', 'detailsLink', 'isCertifiedPartner', 'isEcoCertified', 'isFirstTicket', 'isAuthorizedReseller', \
                 'isGygOriginal', 'imageUrl', 'imageAlt', 'isFreeCancellation', 'smallGroup', 'privateTour', 'hasRating', \
                 'maxPossibleRating', 'totalRating', 'totalRatingTitle', 'averageRatingClass', 'ratingLink', 'languageIds',
                 'ratingStyleModifier', 'ratingStarsClasses', 'ratingTitle', 'hasDuration', 'useValidity', 'validFrom', \
                 'displayAbstract', 'displayDuration', 'displayDate', 'displayWishlist', 'isWishlistAccountWallEnabled', \
                 'displayRemoveButton', 'extraBadges', 'referrerViewPosition', 'hasDiscountedRecommendation', 'urlDetailsBtn', \
                 'hideImage', 'isLikelyToSellOut', 'cardBannerMessage', 'cardBannerType', 'isPromoted', 'isElevated', \
                 'isOutdoors', 'isFamilyFriendly', 'showSkywards', 'skywardsMiles', 'assetsPath', 'isSpecialOffer', \
                 'collectionIdentifier', 'id', 'activityCardVersion', 'limit', 'isLoggedIn', 'timeSlotsExperimentEnabled', \
                 'freeCancellationFlag', 'resultSetPosition', 'highlightedOrientation', 'price.type', \
                 'experiments.hasOriginalsMoneyBackLabel','keyDetails.cancellation_policy.label', 'keyDetails.duration.label',
                 'keyDetails.cancellation_policy.description', 'keyDetails.skip_the_line.label', 'keyDetails.duration.description',
                 'keyDetails.skip_the_line.description', 'keyDetails.instant_confirmation.label', 'keyDetails.instant_confirmation.description'])

df=df.rename(columns={'smallDescription': 'description',
                      'price.original': 'price_original', 'price.min':'price_min',
                      'averageRating':'rating'})

#DATA CLEANING

df['title']=df['title'].str.replace('&#039;', '\'')
df['title']=df['title'].str.replace('&quot;', '\"')
df['title']=df['title'].astype('str')

df['price_min']=df['price_min'].str.replace(" ", "").str.strip('€\xa0\n').str.replace(',', '.').astype('float')

df['price_original']=df['price_original'].str.replace(" ", "").str.strip('€\xa0\n').str.replace(',', '.').astype('float')

df['rating']=df['rating'].fillna('Not rated yet')

df['duration']=df['duration'].str.replace('heures', 'h')
df['duration']=df['duration'].str.replace('heure', 'h')
df['duration']=df['duration'].str.replace('jour', 'day')
df['duration']=df['duration'].str.replace('minutes', 'min')
df['duration']=df['duration'].str.replace(' - ', ' to ')
df['duration']=df['duration'].str.replace(',5 h', 'h30')
df['duration']=df['duration'].str.replace(',5', 'h30')
df['duration']=df['duration'].str.replace('2 880,00 min', '2 days')
df['duration']=df['duration'].str.replace('1 440,00 min', '1 day')
df['duration']=df['duration'].str.replace('90 min', '1h30')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-fdab05a642a4> in <module>
#       1 # COLUMNS
#       2
# ----> 3 df=df.drop_duplicates(subset='tourId')
#       4
#       5 df=df.drop(columns=['tourId', 'horizontalImageUrl', 'verticalImageUrl', 'mobileImageUrl', 'horizontalSlimImageUrl', \
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    4883         diff = Index(subset).difference(self.columns)
#    4884         if not diff.empty:
# -> 4885             raise KeyError(diff)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['tourId'], dtype='object')

# %%
df
# Out:
#                                                 title  \
# 0   Château de Versailles : billet coupe-file et v...
# 1       Visite libre de l'abbaye du Mont-Saint-Michel
# 2                        Chambord : billet coupe-file
# 3   Mont-Saint-Michel : randonnée guidée dans la baie
# 4   Paris : billet d'entrée pour une journée au pa...
# ..                                                ...
# 40  Parc Astérix : transfert privé aller-retour ve...
# 41         Provence Scenic voyage plein Jour de Paris
# 42             Côte d’Azur : tour privé d’une journée
# 43  Transfert privé simple entre Paris et Disneyla...
# 44             Paris : nouveau tour gratuit sans file
#
#                                                   url  \
# 0   https://www.getyourguide.fr/paris-l16/chteau-d...
# 1   https://www.getyourguide.fr/mont-saint-michel-...
# 2   https://www.getyourguide.fr/chteau-de-chambord...
# 3   https://www.getyourguide.fr/granville-l88195/m...
# 4   https://www.getyourguide.fr/paris-l16/billet-d...
# ..                                                ...
# 40  https://www.getyourguide.fr/paris-l16/parc-ast...
# 41  https://www.getyourguide.fr/avignon-l14/excurs...
# 42  https://www.getyourguide.fr/cannes-l15/cte-d-a...
# 43  https://www.getyourguide.fr/paris-l16/transfer...
# 44  https://www.getyourguide.fr/paris-l16/vitez-le...
#
#                                           description         rating duration  \
# 0   Appréciez une visite guidée exclusive de l'un ...            4,7     1h30
# 1   Découvrez l’abbaye du Mont-Saint-Michel, l’un ...            4,6    1 day
# 2   Profitez d'un accès complet au château de Cham...            4,0    1 day
# 3   Appréciez une randonnée guidée dans la baie du...            4,8      3 h
# 4   Passez une journée inoubliable au Parc Astérix...            4,7    1 day
# ..                                                ...            ...      ...
# 40  Profitez d'un service privé de transfert aller...  Not rated yet   50 min
# 41  Découvrez la beauté magnifique de la Provence ...  Not rated yet    15h30
# 42  Découvrez le glamour de la Côte d’Azur en fonc...            4,0      8 h
# 43  Profitez du confort d'un transfert privé entre...            4,6   50 min
# 44  Visitez gratuitement les principales attractio...            4,7      3 h
#
#     price_original  price_min
# 0             45.0       45.0
# 1             11.0       11.0
# 2             14.5       14.5
# 3             15.0       15.0
# 4             43.0       43.0
# ..             ...        ...
# 40            84.0       84.0
# 41           411.0      411.0
# 42           560.0      560.0
# 43            95.6       95.6
# 44             0.0        0.0
#
# [1605 rows x 7 columns]

# %%
#GET CITIES
country=list()
region=list()
city=list()

for urls in df['url']:
    more_infos=r.get(urls, headers=headers)
    soup=BeautifulSoup(more_infos.content)
    place=str(soup.select('.activity__breadcrumbs ul li a'))
    names=re.findall(r'(>[A-z].*?<)', place)
    
    if names:  
        country.append(names[0].strip('><'))
        region.append(names[1].strip('><'))
        city.append(names[2].strip('><'))
    else:
        country.append(0)
        region.append(0)
        city.append(0)
# Out:
# "df['country']=country\ndf['region']=region\ndf['city']=city"

# %%
df['country']=country
df['region']=region
df['city']=city

# %%
df
# Out:
#                                                 title  \
# 0   Château de Versailles : billet coupe-file et v...
# 1       Visite libre de l'abbaye du Mont-Saint-Michel
# 2                        Chambord : billet coupe-file
# 3   Mont-Saint-Michel : randonnée guidée dans la baie
# 4   Paris : billet d'entrée pour une journée au pa...
# ..                                                ...
# 40  Parc Astérix : transfert privé aller-retour ve...
# 41         Provence Scenic voyage plein Jour de Paris
# 42             Côte d’Azur : tour privé d’une journée
# 43  Transfert privé simple entre Paris et Disneyla...
# 44             Paris : nouveau tour gratuit sans file
#
#                                                   url  \
# 0   https://www.getyourguide.fr/paris-l16/chteau-d...
# 1   https://www.getyourguide.fr/mont-saint-michel-...
# 2   https://www.getyourguide.fr/chteau-de-chambord...
# 3   https://www.getyourguide.fr/granville-l88195/m...
# 4   https://www.getyourguide.fr/paris-l16/billet-d...
# ..                                                ...
# 40  https://www.getyourguide.fr/paris-l16/parc-ast...
# 41  https://www.getyourguide.fr/avignon-l14/excurs...
# 42  https://www.getyourguide.fr/cannes-l15/cte-d-a...
# 43  https://www.getyourguide.fr/paris-l16/transfer...
# 44  https://www.getyourguide.fr/paris-l16/vitez-le...
#
#                                           description         rating duration  \
# 0   Appréciez une visite guidée exclusive de l'un ...            4,7     1h30
# 1   Découvrez l’abbaye du Mont-Saint-Michel, l’un ...            4,6    1 day
# 2   Profitez d'un accès complet au château de Cham...            4,0    1 day
# 3   Appréciez une randonnée guidée dans la baie du...            4,8      3 h
# 4   Passez une journée inoubliable au Parc Astérix...            4,7    1 day
# ..                                                ...            ...      ...
# 40  Profitez d'un service privé de transfert aller...  Not rated yet   50 min
# 41  Découvrez la beauté magnifique de la Provence ...  Not rated yet    15h30
# 42  Découvrez le glamour de la Côte d’Azur en fonc...            4,0      8 h
# 43  Profitez du confort d'un transfert privé entre...            4,6   50 min
# 44  Visitez gratuitement les principales attractio...            4,7      3 h
#
#     price_original  price_min country              region  \
# 0             45.0       45.0  France               Paris
# 1             11.0       11.0  France           Normandie
# 2             14.5       14.5  France  Vallée de la Loire
# 3             15.0       15.0  France           Normandie
# 4             43.0       43.0  France               Paris
# ..             ...        ...     ...                 ...
# 40            84.0       84.0  France               Paris
# 41           411.0      411.0  France            Provence
# 42           560.0      560.0  France         Côte d’Azur
# 43            95.6       95.6  France               Paris
# 44             0.0        0.0  France               Paris
#
#                      city
# 0   Château de Versailles
# 1       Mont-Saint-Michel
# 2     Château de Chambord
# 3               Granville
# 4            Parc Astérix
# ..                    ...
# 40           Parc Astérix
# 41                Avignon
# 42                 Cannes
# 43       Disneyland Paris
# 44     Pont Alexandre-III
#
# [1605 rows x 10 columns]

# %%
#COLS SORTING

cols = df.columns.tolist()
cols.insert(1, cols.pop(cols.index('country')))
cols.insert(2, cols.pop(cols.index('region')))
cols.insert(3, cols.pop(cols.index('city')))
cols.insert(4, cols.pop(cols.index('title')))
cols.insert(5, cols.pop(cols.index('description')))
cols.insert(6, cols.pop(cols.index('price_min')))
cols.insert(7, cols.pop(cols.index('price_original')))
cols.insert(8, cols.pop(cols.index('rating')))
cols.insert(9, cols.pop(cols.index('duration')))
cols.insert(10, cols.pop(cols.index('url')))
df = df[cols]

df.reset_index(drop = True, inplace = True)

# %%
"""url_test=['https://www.getyourguide.fr/activity/la-rochelle-l4603/la-rochelle-croisire-en-voilier-au-coucher-du-soleil-de-2-t385700?utm_force=0', 'https://www.getyourguide.fr/activity/les-chteaux-de-la-loire-l7956/chteau-de-chenonceau-billet-d-entre-t176736?utm_force=0', 'https://www.getyourguide.fr/activity/corse-l1534/balade-en-bateau-scandola-girolata-et-calanques-de-piana-t111715?utm_force=0', 'https://getyourguide.fr/activity/arles-l155/depuis-arles-safari-en-camargue-d-une-demi-journe-en-4x4-t221223?utm_force=0', 'https://www.getyourguide.fr/activity/paris-l16/muse-d-orsay-billet-coupe-file-valable-1-journe-t65756?utm_force=0', 'https://www.getyourguide.fr/activity/carcassonne-l1319/carcassonne-chteau-et-remparts-sans-attente-t75012?utm_force=0']

for urls in url_test:
    more_infos=r.get(urls, headers=headers)
    soup=BeautifulSoup(more_infos.content)
    
#GET LANGUAGE
    language=list()

    descr=str(soup.select('.activity-key-details__description'))
    lng=descr.split('\n')[-2].strip('  ')

    language.append(lng)"""

# %%
df
# Out:
#      country              region                   city  \
# 0     France               Paris  Château de Versailles
# 1     France           Normandie      Mont-Saint-Michel
# 2     France  Vallée de la Loire    Château de Chambord
# 3     France           Normandie              Granville
# 4     France               Paris           Parc Astérix
# ...      ...                 ...                    ...
# 1600  France               Paris           Parc Astérix
# 1601  France            Provence                Avignon
# 1602  France         Côte d’Azur                 Cannes
# 1603  France               Paris       Disneyland Paris
# 1604  France               Paris     Pont Alexandre-III
#
#                                                   title  \
# 0     Château de Versailles : billet coupe-file et v...
# 1         Visite libre de l'abbaye du Mont-Saint-Michel
# 2                          Chambord : billet coupe-file
# 3     Mont-Saint-Michel : randonnée guidée dans la baie
# 4     Paris : billet d'entrée pour une journée au pa...
# ...                                                 ...
# 1600  Parc Astérix : transfert privé aller-retour ve...
# 1601         Provence Scenic voyage plein Jour de Paris
# 1602             Côte d’Azur : tour privé d’une journée
# 1603  Transfert privé simple entre Paris et Disneyla...
# 1604             Paris : nouveau tour gratuit sans file
#
#                                             description  price_min  \
# 0     Appréciez une visite guidée exclusive de l'un ...       45.0
# 1     Découvrez l’abbaye du Mont-Saint-Michel, l’un ...       11.0
# 2     Profitez d'un accès complet au château de Cham...       14.5
# 3     Appréciez une randonnée guidée dans la baie du...       15.0
# 4     Passez une journée inoubliable au Parc Astérix...       43.0
# ...                                                 ...        ...
# 1600  Profitez d'un service privé de transfert aller...       84.0
# 1601  Découvrez la beauté magnifique de la Provence ...      411.0
# 1602  Découvrez le glamour de la Côte d’Azur en fonc...      560.0
# 1603  Profitez du confort d'un transfert privé entre...       95.6
# 1604  Visitez gratuitement les principales attractio...        0.0
#
#       price_original         rating duration  \
# 0               45.0            4,7     1h30
# 1               11.0            4,6    1 day
# 2               14.5            4,0    1 day
# 3               15.0            4,8      3 h
# 4               43.0            4,7    1 day
# ...              ...            ...      ...
# 1600            84.0  Not rated yet   50 min
# 1601           411.0  Not rated yet    15h30
# 1602           560.0            4,0      8 h
# 1603            95.6            4,6   50 min
# 1604             0.0            4,7      3 h
#
#                                                     url
# 0     https://www.getyourguide.fr/paris-l16/chteau-d...
# 1     https://www.getyourguide.fr/mont-saint-michel-...
# 2     https://www.getyourguide.fr/chteau-de-chambord...
# 3     https://www.getyourguide.fr/granville-l88195/m...
# 4     https://www.getyourguide.fr/paris-l16/billet-d...
# ...                                                 ...
# 1600  https://www.getyourguide.fr/paris-l16/parc-ast...
# 1601  https://www.getyourguide.fr/avignon-l14/excurs...
# 1602  https://www.getyourguide.fr/cannes-l15/cte-d-a...
# 1603  https://www.getyourguide.fr/paris-l16/transfer...
# 1604  https://www.getyourguide.fr/paris-l16/vitez-le...
#
# [1605 rows x 10 columns]
